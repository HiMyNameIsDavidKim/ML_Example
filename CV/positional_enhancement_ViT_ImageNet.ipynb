# %% [markdown]
# ## Library

# %%
import timm
import torch
import torchvision
import torch.utils.data as data
import torchvision.transforms as transforms
from torch.optim import AdamW, SGD
from torch import nn
from tqdm import tqdm, tqdm_notebook
from torch.optim.lr_scheduler import CosineAnnealingLR

from vit_pooling import ViTPooling
from positional_enhancement import PositionalEnhanceViT


gpu_ids = []
device_names = []
if torch.cuda.is_available():
    for gpu_id in range(torch.cuda.device_count()):
        gpu_ids += [gpu_id]
        device_names += [torch.cuda.get_device_name(gpu_id)]
print(gpu_ids)
print(device_names)

if len(gpu_ids) > 1:
    gpu = 'cuda:' + str(gpu_ids[2])  # GPU Number
else:
    gpu = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# [0, 1, 2, 3]
# ['NVIDIA GeForce RTX 3090', 'NVIDIA GeForce RTX 3090', 'NVIDIA GeForce RTX 3090', 'NVIDIA GeForce RTX 3090']

# %% [markdown]
# ## Hyper parameter

# %%
device = gpu
BATCH_SIZE = 64
NUM_EPOCHS = 12
NUM_WORKERS = 2
LEARNING_RATE = 3e-04
pre_model_path = f'./save/ViT_timm_vit_base_patch16_224_in21k_positionBaselineEp{NUM_EPOCHS}.pt'
fine_model_path = f'./save/ViT_timm_vit_base_patch16_224_in21k_positionBaselineEp8_position_i2012_ep{NUM_EPOCHS}_lr{LEARNING_RATE}.pt'
pre_load_model_path = f'./save/ViT_timm_vit_base_patch16_224_in21k_positionBaselineEp8.pt'
fine_load_model_path = f'./save/ViT_timm_vit_base_patch16_224_in21k_positionBaselineEp8.pt'

NUM_CLASSES = 1000
WEIGHT_DECAY = 0.1

# %% [markdown]
# ## Dataset

# %%
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
transform_test = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
# pre_train_set = torchvision.datasets.ImageFolder('./data/ImageNet-21k', transform=transform_train)
# pre_train_loader = data.DataLoader(pre_train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
train_set = torchvision.datasets.ImageFolder('../../YJ/ILSVRC2012/train', transform=transform_train)
train_loader = data.DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
test_set = torchvision.datasets.ImageFolder('../../YJ/ILSVRC2012/val', transform=transform_test)
test_loader = data.DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

# %% [markdown]
# ## Pre-training Class

# %%
class PreTrainer(object):
    def __init__(self):
        self.model = None
        self.optimizer = None
        self.epochs = []
        self.losses = []

    def process(self, load=False):
        self.build_model(load)
        self.pretrain_model()
        self.save_model()

    def build_model(self, load):
        self.model = PositionalEnhanceViT(NUM_CLASSES).to(device)
        print(f'Parameter: {sum(p.numel() for p in self.model.parameters() if p.requires_grad)}')
        print(f'Classes: {self.model.num_classes}')
        self.optimizer = AdamW(self.model.parameters(), lr=0)
        if load:
            checkpoint = torch.load(pre_load_model_path)
            self.epochs = checkpoint['epochs']
            self.model.load_state_dict(checkpoint['model'])
            self.losses = checkpoint['losses']
            print(f'Parameter: {sum(p.numel() for p in self.model.parameters() if p.requires_grad)}')
            print(f'Classes: {self.model.num_classes}')
            print(f'Epoch: {self.epochs[-1]}')
            print(f'****** Reset epochs and losses ******')
            self.epochs = []
            self.losses = []

    def pretrain_model(self):
        model = self.model
        criterion = nn.CrossEntropyLoss()
        optimizer = AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)

        for epoch in range(NUM_EPOCHS):
            running_loss = 0.0
            saving_loss = 0.0
            for i, data in tqdm_notebook(enumerate(train_loader, 0), total=len(train_loader)):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                saving_loss += loss.item()
                if i % 100 == 99:
                    print(f'[Epoch {epoch}, Batch {i + 1:5d}] loss: {running_loss / 100:.3f}')
                    running_loss = 0.0
                if i % 1000 == 999:
                    self.epochs.append(epoch+1)
                    self.model = model
                    self.optimizer = optimizer
                    self.losses.append(saving_loss/1000)
                    self.save_model()
                    saving_loss = 0.0
            scheduler.step()
        print('****** Finished Pre-training ******')
        self.model = model

    def save_model(self):
        checkpoint = {
            'epochs': self.epochs,
            'model': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'losses': self.losses,
        }
        torch.save(checkpoint, pre_model_path)
        print(f"****** Model checkpoint saved at epochs {self.epochs[-1]} ******")

# %% [markdown]
# ## Fine-tuning Class

# %%
class FineTunner(object):
    def __init__(self):
        self.model = None
        self.optimizer = None
        self.epochs = []
        self.losses = []

    def process(self, load=False):
        self.build_model(load)
        self.finetune_model()
        self.save_model()

    def build_model(self, load):
        self.model = PositionalEnhanceViT(NUM_CLASSES).to(device)
        for param in self.model.forward_vit.parameters():
            param.requires_grad = True
        print(f'Parameter: {sum(p.numel() for p in self.model.parameters() if p.requires_grad)}')
        print(f'Classes: {self.model.num_classes}')
        self.optimizer = SGD(self.model.parameters(), lr=0)
        if load:
            checkpoint = torch.load(fine_load_model_path)
            self.epochs = checkpoint['epochs']
            self.model.load_state_dict(checkpoint['model'])
            self.losses = checkpoint['losses']
            print(f'Parameter: {sum(p.numel() for p in self.model.parameters() if p.requires_grad)}')
            print(f'Classes: {self.model.num_classes}')
            print(f'Epoch: {self.epochs[-1]}')
            print(f'****** Reset epochs and losses ******')
            self.epochs = []
            self.losses = []

    def finetune_model(self):
        model = self.model
        criterion = nn.CrossEntropyLoss()
        optimizer = SGD(model.parameters(), lr=LEARNING_RATE, momentum=0.9)
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)

        for epoch in range(NUM_EPOCHS):
            running_loss = 0.0
            saving_loss = 0.0
            for i, data in tqdm_notebook(enumerate(train_loader, 0), total=len(train_loader)):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                saving_loss += loss.item()
                if i % 100 == 99:
                    print(f'[Epoch {epoch}, Batch {i + 1:5d}] loss: {running_loss / 100:.3f}')
                    running_loss = 0.0
                if i % 1000 == 999:
                    self.epochs.append(epoch + 1)
                    self.model = model
                    self.optimizer = optimizer
                    self.losses.append(saving_loss/1000)
                    self.save_model()
                    saving_loss = 0.0
            scheduler.step()
        print('****** Finished Fine-tuning ******')
        self.model = model

    def save_model(self):
        checkpoint = {
            'epochs': self.epochs,
            'model': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'losses': self.losses,
        }
        torch.save(checkpoint, fine_model_path)
#         torch.save(checkpoint, dynamic_model_path+str(self.epochs[-1])+f'_lr{LEARNING_RATE}.pt')
        print(f"****** Model checkpoint saved at epochs {self.epochs[-1]} ******")

# %%
if __name__ == '__main__':
    trainer = FineTunner()
    trainer.process(load=True)
# Out:
# Parameter: 107883659
# Classes: 1000
# Parameter: 107883659
# Classes: 1000
# Epoch: 8
# ****** Reset epochs and losses ******
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/20019 [00:00<?, ?it/s]
# [Epoch 0, Batch   100] loss: 1.033
# [Epoch 0, Batch   200] loss: 1.022
# [Epoch 0, Batch   300] loss: 1.048
# [Epoch 0, Batch   400] loss: 1.048
# [Epoch 0, Batch   500] loss: 1.059
# [Epoch 0, Batch   600] loss: 1.027
# [Epoch 0, Batch   700] loss: 1.053
# [Epoch 0, Batch   800] loss: 1.047
# [Epoch 0, Batch   900] loss: 1.069
# [Epoch 0, Batch  1000] loss: 1.036
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  1100] loss: 1.040
# [Epoch 0, Batch  1200] loss: 1.008
# [Epoch 0, Batch  1300] loss: 1.012
# [Epoch 0, Batch  1400] loss: 1.014
# [Epoch 0, Batch  1500] loss: 1.023
# [Epoch 0, Batch  1600] loss: 1.024
# [Epoch 0, Batch  1700] loss: 1.027
# [Epoch 0, Batch  1800] loss: 0.995
# [Epoch 0, Batch  1900] loss: 1.019
# [Epoch 0, Batch  2000] loss: 1.075
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  2100] loss: 0.995
# [Epoch 0, Batch  2200] loss: 0.984
# [Epoch 0, Batch  2300] loss: 1.010
# [Epoch 0, Batch  2400] loss: 1.034
# [Epoch 0, Batch  2500] loss: 0.971
# [Epoch 0, Batch  2600] loss: 1.009
# [Epoch 0, Batch  2700] loss: 0.998
# [Epoch 0, Batch  2800] loss: 0.954
# [Epoch 0, Batch  2900] loss: 0.983
# [Epoch 0, Batch  3000] loss: 1.005
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  3100] loss: 1.016
# [Epoch 0, Batch  3200] loss: 0.994
# [Epoch 0, Batch  3300] loss: 1.015
# [Epoch 0, Batch  3400] loss: 0.986
# [Epoch 0, Batch  3500] loss: 1.015
# [Epoch 0, Batch  3600] loss: 0.978
# [Epoch 0, Batch  3700] loss: 0.964
# [Epoch 0, Batch  3800] loss: 0.991
# [Epoch 0, Batch  3900] loss: 1.020
# [Epoch 0, Batch  4000] loss: 0.994
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  4100] loss: 1.001
# [Epoch 0, Batch  4200] loss: 1.030
# [Epoch 0, Batch  4300] loss: 1.013
# [Epoch 0, Batch  4400] loss: 0.997
# [Epoch 0, Batch  4500] loss: 0.970
# [Epoch 0, Batch  4600] loss: 0.988
# [Epoch 0, Batch  4700] loss: 0.984
# [Epoch 0, Batch  4800] loss: 0.953
# [Epoch 0, Batch  4900] loss: 0.961
# [Epoch 0, Batch  5000] loss: 0.992
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  5100] loss: 0.990
# [Epoch 0, Batch  5200] loss: 0.997
# [Epoch 0, Batch  5300] loss: 0.969
# [Epoch 0, Batch  5400] loss: 0.972
# [Epoch 0, Batch  5500] loss: 0.950
# [Epoch 0, Batch  5600] loss: 0.974
# [Epoch 0, Batch  5700] loss: 0.987
# [Epoch 0, Batch  5800] loss: 0.956
# [Epoch 0, Batch  5900] loss: 0.969
# [Epoch 0, Batch  6000] loss: 1.000
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  6100] loss: 0.983
# [Epoch 0, Batch  6200] loss: 0.984
# [Epoch 0, Batch  6300] loss: 0.982
# [Epoch 0, Batch  6400] loss: 0.964
# [Epoch 0, Batch  6500] loss: 0.964
# [Epoch 0, Batch  6600] loss: 0.987
# [Epoch 0, Batch  6700] loss: 0.979
# [Epoch 0, Batch  6800] loss: 0.947
# [Epoch 0, Batch  6900] loss: 0.974
# [Epoch 0, Batch  7000] loss: 0.987
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  7100] loss: 0.980
# [Epoch 0, Batch  7200] loss: 0.967
# [Epoch 0, Batch  7300] loss: 0.961
# [Epoch 0, Batch  7400] loss: 0.995
# [Epoch 0, Batch  7500] loss: 0.981
# [Epoch 0, Batch  7600] loss: 0.979
# [Epoch 0, Batch  7700] loss: 0.928
# [Epoch 0, Batch  7800] loss: 0.951
# [Epoch 0, Batch  7900] loss: 0.944
# [Epoch 0, Batch  8000] loss: 0.985
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  8100] loss: 0.947
# [Epoch 0, Batch  8200] loss: 0.931
# [Epoch 0, Batch  8300] loss: 0.986
# [Epoch 0, Batch  8400] loss: 0.944
# [Epoch 0, Batch  8500] loss: 0.961
# [Epoch 0, Batch  8600] loss: 0.985
# [Epoch 0, Batch  8700] loss: 0.948
# [Epoch 0, Batch  8800] loss: 1.028
# [Epoch 0, Batch  8900] loss: 0.961
# [Epoch 0, Batch  9000] loss: 0.956
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch  9100] loss: 0.945
# [Epoch 0, Batch  9200] loss: 0.970
# [Epoch 0, Batch  9300] loss: 1.014
# [Epoch 0, Batch  9400] loss: 0.962
# [Epoch 0, Batch  9500] loss: 0.945
# [Epoch 0, Batch  9600] loss: 0.931
# [Epoch 0, Batch  9700] loss: 0.959
# [Epoch 0, Batch  9800] loss: 0.990
# [Epoch 0, Batch  9900] loss: 0.985
# [Epoch 0, Batch 10000] loss: 0.951
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 10100] loss: 0.962
# [Epoch 0, Batch 10200] loss: 0.981
# [Epoch 0, Batch 10300] loss: 0.942
# [Epoch 0, Batch 10400] loss: 0.974
# [Epoch 0, Batch 10500] loss: 1.005
# [Epoch 0, Batch 10600] loss: 0.963
# [Epoch 0, Batch 10700] loss: 0.924
# [Epoch 0, Batch 10800] loss: 0.954
# [Epoch 0, Batch 10900] loss: 0.955
# [Epoch 0, Batch 11000] loss: 0.969
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 11100] loss: 0.968
# [Epoch 0, Batch 11200] loss: 0.990
# [Epoch 0, Batch 11300] loss: 0.968
# [Epoch 0, Batch 11400] loss: 0.946
# [Epoch 0, Batch 11500] loss: 0.985
# [Epoch 0, Batch 11600] loss: 0.952
# [Epoch 0, Batch 11700] loss: 0.952
# [Epoch 0, Batch 11800] loss: 0.972
# [Epoch 0, Batch 11900] loss: 0.943
# [Epoch 0, Batch 12000] loss: 0.952
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 12100] loss: 0.935
# [Epoch 0, Batch 12200] loss: 0.999
# [Epoch 0, Batch 12300] loss: 0.963
# [Epoch 0, Batch 12400] loss: 0.946
# [Epoch 0, Batch 12500] loss: 0.927
# [Epoch 0, Batch 12600] loss: 0.939
# [Epoch 0, Batch 12700] loss: 0.892
# [Epoch 0, Batch 12800] loss: 0.915
# [Epoch 0, Batch 12900] loss: 0.961
# [Epoch 0, Batch 13000] loss: 0.957
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 13100] loss: 0.931
# [Epoch 0, Batch 13200] loss: 0.950
# [Epoch 0, Batch 13300] loss: 0.975
# [Epoch 0, Batch 13400] loss: 0.982
# [Epoch 0, Batch 13500] loss: 0.912
# [Epoch 0, Batch 13600] loss: 0.929
# [Epoch 0, Batch 13700] loss: 0.963
# [Epoch 0, Batch 13800] loss: 0.894
# [Epoch 0, Batch 13900] loss: 0.947
# [Epoch 0, Batch 14000] loss: 0.900
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 14100] loss: 0.944
# [Epoch 0, Batch 14200] loss: 0.968
# [Epoch 0, Batch 14300] loss: 0.912
# [Epoch 0, Batch 14400] loss: 0.958
# [Epoch 0, Batch 14500] loss: 0.949
# [Epoch 0, Batch 14600] loss: 0.967
# [Epoch 0, Batch 14700] loss: 0.945
# [Epoch 0, Batch 14800] loss: 0.966
# [Epoch 0, Batch 14900] loss: 0.937
# [Epoch 0, Batch 15000] loss: 0.943
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 15100] loss: 0.959
# [Epoch 0, Batch 15200] loss: 0.949
# [Epoch 0, Batch 15300] loss: 0.986
# [Epoch 0, Batch 15400] loss: 0.939
# [Epoch 0, Batch 15500] loss: 0.946
# [Epoch 0, Batch 15600] loss: 0.991
# [Epoch 0, Batch 15700] loss: 0.952
# [Epoch 0, Batch 15800] loss: 0.905
# [Epoch 0, Batch 15900] loss: 0.925
# [Epoch 0, Batch 16000] loss: 0.938
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 16100] loss: 0.965
# [Epoch 0, Batch 16200] loss: 0.953
# [Epoch 0, Batch 16300] loss: 0.982
# [Epoch 0, Batch 16400] loss: 0.960
# [Epoch 0, Batch 16500] loss: 0.947
# [Epoch 0, Batch 16600] loss: 0.920
# [Epoch 0, Batch 16700] loss: 0.942
# [Epoch 0, Batch 16800] loss: 0.960
# [Epoch 0, Batch 16900] loss: 0.905
# [Epoch 0, Batch 17000] loss: 0.961
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 17100] loss: 0.943
# [Epoch 0, Batch 17200] loss: 0.882
# [Epoch 0, Batch 17300] loss: 0.921
# [Epoch 0, Batch 17400] loss: 0.942
# [Epoch 0, Batch 17500] loss: 0.915
# [Epoch 0, Batch 17600] loss: 0.962
# [Epoch 0, Batch 17700] loss: 0.946
# [Epoch 0, Batch 17800] loss: 0.920
# [Epoch 0, Batch 17900] loss: 0.947
# [Epoch 0, Batch 18000] loss: 0.945
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 18100] loss: 0.888
# [Epoch 0, Batch 18200] loss: 0.928
# [Epoch 0, Batch 18300] loss: 0.894
# [Epoch 0, Batch 18400] loss: 0.957
# [Epoch 0, Batch 18500] loss: 0.941
# [Epoch 0, Batch 18600] loss: 0.904
# [Epoch 0, Batch 18700] loss: 0.912
# [Epoch 0, Batch 18800] loss: 0.928
# [Epoch 0, Batch 18900] loss: 0.937
# [Epoch 0, Batch 19000] loss: 0.911
# ****** Model checkpoint saved at epochs 1 ******
# [Epoch 0, Batch 19100] loss: 0.959
# [Epoch 0, Batch 19200] loss: 0.950
# [Epoch 0, Batch 19300] loss: 0.925
# [Epoch 0, Batch 19400] loss: 0.869
# [Epoch 0, Batch 19500] loss: 0.880
# [Epoch 0, Batch 19600] loss: 0.951
# [Epoch 0, Batch 19700] loss: 0.941
# [Epoch 0, Batch 19800] loss: 0.953
# [Epoch 0, Batch 19900] loss: 0.946
# [Epoch 0, Batch 20000] loss: 0.916
# ****** Model checkpoint saved at epochs 1 ******
#   0%|          | 0/20019 [00:00<?, ?it/s]
# [Epoch 1, Batch   100] loss: 0.896
# [Epoch 1, Batch   200] loss: 0.902
# [Epoch 1, Batch   300] loss: 0.895
# [Epoch 1, Batch   400] loss: 0.888
# [Epoch 1, Batch   500] loss: 0.857
# [Epoch 1, Batch   600] loss: 0.861
# [Epoch 1, Batch   700] loss: 0.910
# [Epoch 1, Batch   800] loss: 0.897
# [Epoch 1, Batch   900] loss: 0.863
# [Epoch 1, Batch  1000] loss: 0.912
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  1100] loss: 0.895
# [Epoch 1, Batch  1200] loss: 0.898
# [Epoch 1, Batch  1300] loss: 0.879
# [Epoch 1, Batch  1400] loss: 0.881
# [Epoch 1, Batch  1500] loss: 0.875
# [Epoch 1, Batch  1600] loss: 0.874
# [Epoch 1, Batch  1700] loss: 0.887
# [Epoch 1, Batch  1800] loss: 0.912
# [Epoch 1, Batch  1900] loss: 0.844
# [Epoch 1, Batch  2000] loss: 0.850
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  2100] loss: 0.843
# [Epoch 1, Batch  2200] loss: 0.859
# [Epoch 1, Batch  2300] loss: 0.866
# [Epoch 1, Batch  2400] loss: 0.856
# [Epoch 1, Batch  2500] loss: 0.855
# [Epoch 1, Batch  2600] loss: 0.854
# [Epoch 1, Batch  2700] loss: 0.905
# [Epoch 1, Batch  2800] loss: 0.913
# [Epoch 1, Batch  2900] loss: 0.907
# [Epoch 1, Batch  3000] loss: 0.867
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  3100] loss: 0.881
# [Epoch 1, Batch  3200] loss: 0.929
# [Epoch 1, Batch  3300] loss: 0.907
# [Epoch 1, Batch  3400] loss: 0.935
# [Epoch 1, Batch  3500] loss: 0.917
# [Epoch 1, Batch  3600] loss: 0.928
# [Epoch 1, Batch  3700] loss: 0.906
# [Epoch 1, Batch  3800] loss: 0.868
# [Epoch 1, Batch  3900] loss: 0.862
# [Epoch 1, Batch  4000] loss: 0.890
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  4100] loss: 0.914
# [Epoch 1, Batch  4200] loss: 0.864
# [Epoch 1, Batch  4300] loss: 0.893
# [Epoch 1, Batch  4400] loss: 0.879
# [Epoch 1, Batch  4500] loss: 0.895
# [Epoch 1, Batch  4600] loss: 0.921
# [Epoch 1, Batch  4700] loss: 0.898
# [Epoch 1, Batch  4800] loss: 0.860
# [Epoch 1, Batch  4900] loss: 0.891
# [Epoch 1, Batch  5000] loss: 0.850
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  5100] loss: 0.925
# [Epoch 1, Batch  5200] loss: 0.900
# [Epoch 1, Batch  5300] loss: 0.869
# [Epoch 1, Batch  5400] loss: 0.872
# [Epoch 1, Batch  5500] loss: 0.921
# [Epoch 1, Batch  5600] loss: 0.842
# [Epoch 1, Batch  5700] loss: 0.905
# [Epoch 1, Batch  5800] loss: 0.874
# [Epoch 1, Batch  5900] loss: 0.893
# [Epoch 1, Batch  6000] loss: 0.879
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  6100] loss: 0.869
# [Epoch 1, Batch  6200] loss: 0.874
# [Epoch 1, Batch  6300] loss: 0.875
# [Epoch 1, Batch  6400] loss: 0.863
# [Epoch 1, Batch  6500] loss: 0.876
# [Epoch 1, Batch  6600] loss: 0.893
# [Epoch 1, Batch  6700] loss: 0.904
# [Epoch 1, Batch  6800] loss: 0.891
# [Epoch 1, Batch  6900] loss: 0.874
# [Epoch 1, Batch  7000] loss: 0.868
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  7100] loss: 0.890
# [Epoch 1, Batch  7200] loss: 0.893
# [Epoch 1, Batch  7300] loss: 0.946
# [Epoch 1, Batch  7400] loss: 0.884
# [Epoch 1, Batch  7500] loss: 0.892
# [Epoch 1, Batch  7600] loss: 0.878
# [Epoch 1, Batch  7700] loss: 0.866
# [Epoch 1, Batch  7800] loss: 0.843
# [Epoch 1, Batch  7900] loss: 0.873
# [Epoch 1, Batch  8000] loss: 0.874
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  8100] loss: 0.862
# [Epoch 1, Batch  8200] loss: 0.856
# [Epoch 1, Batch  8300] loss: 0.896
# [Epoch 1, Batch  8400] loss: 0.885
# [Epoch 1, Batch  8500] loss: 0.859
# [Epoch 1, Batch  8600] loss: 0.911
# [Epoch 1, Batch  8700] loss: 0.856
# [Epoch 1, Batch  8800] loss: 0.892
# [Epoch 1, Batch  8900] loss: 0.845
# [Epoch 1, Batch  9000] loss: 0.869
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch  9100] loss: 0.888
# [Epoch 1, Batch  9200] loss: 0.880
# [Epoch 1, Batch  9300] loss: 0.872
# [Epoch 1, Batch  9400] loss: 0.856
# [Epoch 1, Batch  9500] loss: 0.867
# [Epoch 1, Batch  9600] loss: 0.889
# [Epoch 1, Batch  9700] loss: 0.863
# [Epoch 1, Batch  9800] loss: 0.876
# [Epoch 1, Batch  9900] loss: 0.914
# [Epoch 1, Batch 10000] loss: 0.859
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 10100] loss: 0.877
# [Epoch 1, Batch 10200] loss: 0.880
# [Epoch 1, Batch 10300] loss: 0.879
# [Epoch 1, Batch 10400] loss: 0.879
# [Epoch 1, Batch 10500] loss: 0.877
# [Epoch 1, Batch 10600] loss: 0.865
# [Epoch 1, Batch 10700] loss: 0.911
# [Epoch 1, Batch 10800] loss: 0.836
# [Epoch 1, Batch 10900] loss: 0.888
# [Epoch 1, Batch 11000] loss: 0.874
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 11100] loss: 0.864
# [Epoch 1, Batch 11200] loss: 0.857
# [Epoch 1, Batch 11300] loss: 0.841
# [Epoch 1, Batch 11400] loss: 0.931
# [Epoch 1, Batch 11500] loss: 0.875
# [Epoch 1, Batch 11600] loss: 0.892
# [Epoch 1, Batch 11700] loss: 0.885
# [Epoch 1, Batch 11800] loss: 0.882
# [Epoch 1, Batch 11900] loss: 0.853
# [Epoch 1, Batch 12000] loss: 0.880
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 12100] loss: 0.894
# [Epoch 1, Batch 12200] loss: 0.855
# [Epoch 1, Batch 12300] loss: 0.831
# [Epoch 1, Batch 12400] loss: 0.900
# [Epoch 1, Batch 12500] loss: 0.871
# [Epoch 1, Batch 12600] loss: 0.887
# [Epoch 1, Batch 12700] loss: 0.928
# [Epoch 1, Batch 12800] loss: 0.870
# [Epoch 1, Batch 12900] loss: 0.912
# [Epoch 1, Batch 13000] loss: 0.842
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 13100] loss: 0.874
# [Epoch 1, Batch 13200] loss: 0.872
# [Epoch 1, Batch 13300] loss: 0.866
# [Epoch 1, Batch 13400] loss: 0.896
# [Epoch 1, Batch 13500] loss: 0.862
# [Epoch 1, Batch 13600] loss: 0.890
# [Epoch 1, Batch 13700] loss: 0.883
# [Epoch 1, Batch 13800] loss: 0.834
# [Epoch 1, Batch 13900] loss: 0.900
# [Epoch 1, Batch 14000] loss: 0.886
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 14100] loss: 0.878
# [Epoch 1, Batch 14200] loss: 0.849
# [Epoch 1, Batch 14300] loss: 0.884
# [Epoch 1, Batch 14400] loss: 0.868
# [Epoch 1, Batch 14500] loss: 0.873
# [Epoch 1, Batch 14600] loss: 0.886
# [Epoch 1, Batch 14700] loss: 0.879
# [Epoch 1, Batch 14800] loss: 0.883
# [Epoch 1, Batch 14900] loss: 0.852
# [Epoch 1, Batch 15000] loss: 0.873
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 15100] loss: 0.903
# [Epoch 1, Batch 15200] loss: 0.864
# [Epoch 1, Batch 15300] loss: 0.842
# [Epoch 1, Batch 15400] loss: 0.866
# [Epoch 1, Batch 15500] loss: 0.902
# [Epoch 1, Batch 15600] loss: 0.897
# [Epoch 1, Batch 15700] loss: 0.880
# [Epoch 1, Batch 15800] loss: 0.840
# [Epoch 1, Batch 15900] loss: 0.870
# [Epoch 1, Batch 16000] loss: 0.872
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 16100] loss: 0.828
# [Epoch 1, Batch 16200] loss: 0.882
# [Epoch 1, Batch 16300] loss: 0.877
# [Epoch 1, Batch 16400] loss: 0.860
# [Epoch 1, Batch 16500] loss: 0.899
# [Epoch 1, Batch 16600] loss: 0.891
# [Epoch 1, Batch 16700] loss: 0.862
# [Epoch 1, Batch 16800] loss: 0.910
# [Epoch 1, Batch 16900] loss: 0.891
# [Epoch 1, Batch 17000] loss: 0.859
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 17100] loss: 0.866
# [Epoch 1, Batch 17200] loss: 0.892
# [Epoch 1, Batch 17300] loss: 0.855
# [Epoch 1, Batch 17400] loss: 0.934
# [Epoch 1, Batch 17500] loss: 0.873
# [Epoch 1, Batch 17600] loss: 0.849
# [Epoch 1, Batch 17700] loss: 0.892
# [Epoch 1, Batch 17800] loss: 0.901
# [Epoch 1, Batch 17900] loss: 0.833
# [Epoch 1, Batch 18000] loss: 0.865
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 18100] loss: 0.851
# [Epoch 1, Batch 18200] loss: 0.842
# [Epoch 1, Batch 18300] loss: 0.871
# [Epoch 1, Batch 18400] loss: 0.873
# [Epoch 1, Batch 18500] loss: 0.871
# [Epoch 1, Batch 18600] loss: 0.879
# [Epoch 1, Batch 18700] loss: 0.880
# [Epoch 1, Batch 18800] loss: 0.884
# [Epoch 1, Batch 18900] loss: 0.880
# [Epoch 1, Batch 19000] loss: 0.841
# ****** Model checkpoint saved at epochs 2 ******
# [Epoch 1, Batch 19100] loss: 0.857
# [Epoch 1, Batch 19200] loss: 0.869
# [Epoch 1, Batch 19300] loss: 0.865
# [Epoch 1, Batch 19400] loss: 0.852
# [Epoch 1, Batch 19500] loss: 0.901
# [Epoch 1, Batch 19600] loss: 0.867
# [Epoch 1, Batch 19700] loss: 0.861
# [Epoch 1, Batch 19800] loss: 0.860
# [Epoch 1, Batch 19900] loss: 0.912
# [Epoch 1, Batch 20000] loss: 0.884
# ****** Model checkpoint saved at epochs 2 ******
#   0%|          | 0/20019 [00:00<?, ?it/s]
# [Epoch 2, Batch   100] loss: 0.833
# [Epoch 2, Batch   200] loss: 0.807
# [Epoch 2, Batch   300] loss: 0.800
# [Epoch 2, Batch   400] loss: 0.795
# [Epoch 2, Batch   500] loss: 0.826
# [Epoch 2, Batch   600] loss: 0.818
# [Epoch 2, Batch   700] loss: 0.794
# [Epoch 2, Batch   800] loss: 0.840
# [Epoch 2, Batch   900] loss: 0.827
# [Epoch 2, Batch  1000] loss: 0.810
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  1100] loss: 0.814
# [Epoch 2, Batch  1200] loss: 0.799
# [Epoch 2, Batch  1300] loss: 0.799
# [Epoch 2, Batch  1400] loss: 0.820
# [Epoch 2, Batch  1500] loss: 0.770
# [Epoch 2, Batch  1600] loss: 0.786
# [Epoch 2, Batch  1700] loss: 0.829
# [Epoch 2, Batch  1800] loss: 0.845
# [Epoch 2, Batch  1900] loss: 0.806
# [Epoch 2, Batch  2000] loss: 0.823
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  2100] loss: 0.795
# [Epoch 2, Batch  2200] loss: 0.834
# [Epoch 2, Batch  2300] loss: 0.833
# [Epoch 2, Batch  2400] loss: 0.859
# [Epoch 2, Batch  2500] loss: 0.829
# [Epoch 2, Batch  2600] loss: 0.820
# [Epoch 2, Batch  2700] loss: 0.824
# [Epoch 2, Batch  2800] loss: 0.824
# [Epoch 2, Batch  2900] loss: 0.809
# [Epoch 2, Batch  3000] loss: 0.837
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  3100] loss: 0.855
# [Epoch 2, Batch  3200] loss: 0.819
# [Epoch 2, Batch  3300] loss: 0.831
# [Epoch 2, Batch  3400] loss: 0.840
# [Epoch 2, Batch  3500] loss: 0.820
# [Epoch 2, Batch  3600] loss: 0.833
# [Epoch 2, Batch  3700] loss: 0.837
# [Epoch 2, Batch  3800] loss: 0.828
# [Epoch 2, Batch  3900] loss: 0.855
# [Epoch 2, Batch  4000] loss: 0.834
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  4100] loss: 0.835
# [Epoch 2, Batch  4200] loss: 0.847
# [Epoch 2, Batch  4300] loss: 0.876
# [Epoch 2, Batch  4400] loss: 0.840
# [Epoch 2, Batch  4500] loss: 0.816
# [Epoch 2, Batch  4600] loss: 0.831
# [Epoch 2, Batch  4700] loss: 0.828
# [Epoch 2, Batch  4800] loss: 0.826
# [Epoch 2, Batch  4900] loss: 0.782
# [Epoch 2, Batch  5000] loss: 0.813
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  5100] loss: 0.814
# [Epoch 2, Batch  5200] loss: 0.821
# [Epoch 2, Batch  5300] loss: 0.818
# [Epoch 2, Batch  5400] loss: 0.829
# [Epoch 2, Batch  5500] loss: 0.820
# [Epoch 2, Batch  5600] loss: 0.828
# [Epoch 2, Batch  5700] loss: 0.830
# [Epoch 2, Batch  5800] loss: 0.755
# [Epoch 2, Batch  5900] loss: 0.851
# [Epoch 2, Batch  6000] loss: 0.837
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  6100] loss: 0.826
# [Epoch 2, Batch  6200] loss: 0.847
# [Epoch 2, Batch  6300] loss: 0.859
# [Epoch 2, Batch  6400] loss: 0.827
# [Epoch 2, Batch  6500] loss: 0.813
# [Epoch 2, Batch  6600] loss: 0.846
# [Epoch 2, Batch  6700] loss: 0.851
# [Epoch 2, Batch  6800] loss: 0.828
# [Epoch 2, Batch  6900] loss: 0.831
# [Epoch 2, Batch  7000] loss: 0.813
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  7100] loss: 0.835
# [Epoch 2, Batch  7200] loss: 0.854
# [Epoch 2, Batch  7300] loss: 0.847
# [Epoch 2, Batch  7400] loss: 0.828
# [Epoch 2, Batch  7500] loss: 0.816
# [Epoch 2, Batch  7600] loss: 0.821
# [Epoch 2, Batch  7700] loss: 0.832
# [Epoch 2, Batch  7800] loss: 0.839
# [Epoch 2, Batch  7900] loss: 0.878
# [Epoch 2, Batch  8000] loss: 0.813
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  8100] loss: 0.813
# [Epoch 2, Batch  8200] loss: 0.820
# [Epoch 2, Batch  8300] loss: 0.828
# [Epoch 2, Batch  8400] loss: 0.846
# [Epoch 2, Batch  8500] loss: 0.807
# [Epoch 2, Batch  8600] loss: 0.807
# [Epoch 2, Batch  8700] loss: 0.814
# [Epoch 2, Batch  8800] loss: 0.816
# [Epoch 2, Batch  8900] loss: 0.813
# [Epoch 2, Batch  9000] loss: 0.839
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch  9100] loss: 0.812
# [Epoch 2, Batch  9200] loss: 0.807
# [Epoch 2, Batch  9300] loss: 0.842
# [Epoch 2, Batch  9400] loss: 0.827
# [Epoch 2, Batch  9500] loss: 0.837
# [Epoch 2, Batch  9600] loss: 0.827
# [Epoch 2, Batch  9700] loss: 0.849
# [Epoch 2, Batch  9800] loss: 0.827
# [Epoch 2, Batch  9900] loss: 0.814
# [Epoch 2, Batch 10000] loss: 0.817
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 10100] loss: 0.832
# [Epoch 2, Batch 10200] loss: 0.813
# [Epoch 2, Batch 10300] loss: 0.842
# [Epoch 2, Batch 10400] loss: 0.782
# [Epoch 2, Batch 10500] loss: 0.828
# [Epoch 2, Batch 10600] loss: 0.842
# [Epoch 2, Batch 10700] loss: 0.802
# [Epoch 2, Batch 10800] loss: 0.851
# [Epoch 2, Batch 10900] loss: 0.861
# [Epoch 2, Batch 11000] loss: 0.831
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 11100] loss: 0.803
# [Epoch 2, Batch 11200] loss: 0.817
# [Epoch 2, Batch 11300] loss: 0.847
# [Epoch 2, Batch 11400] loss: 0.796
# [Epoch 2, Batch 11500] loss: 0.827
# [Epoch 2, Batch 11600] loss: 0.846
# [Epoch 2, Batch 11700] loss: 0.823
# [Epoch 2, Batch 11800] loss: 0.812
# [Epoch 2, Batch 11900] loss: 0.830
# [Epoch 2, Batch 12000] loss: 0.850
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 12100] loss: 0.818
# [Epoch 2, Batch 12200] loss: 0.842
# [Epoch 2, Batch 12300] loss: 0.787
# [Epoch 2, Batch 12400] loss: 0.818
# [Epoch 2, Batch 12500] loss: 0.827
# [Epoch 2, Batch 12600] loss: 0.765
# [Epoch 2, Batch 12700] loss: 0.831
# [Epoch 2, Batch 12800] loss: 0.856
# [Epoch 2, Batch 12900] loss: 0.835
# [Epoch 2, Batch 13000] loss: 0.831
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 13100] loss: 0.880
# [Epoch 2, Batch 13200] loss: 0.830
# [Epoch 2, Batch 13300] loss: 0.848
# [Epoch 2, Batch 13400] loss: 0.849
# [Epoch 2, Batch 13500] loss: 0.819
# [Epoch 2, Batch 13600] loss: 0.817
# [Epoch 2, Batch 13700] loss: 0.822
# [Epoch 2, Batch 13800] loss: 0.818
# [Epoch 2, Batch 13900] loss: 0.781
# [Epoch 2, Batch 14000] loss: 0.822
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 14100] loss: 0.817
# [Epoch 2, Batch 14200] loss: 0.845
# [Epoch 2, Batch 14300] loss: 0.859
# [Epoch 2, Batch 14400] loss: 0.828
# [Epoch 2, Batch 14500] loss: 0.840
# [Epoch 2, Batch 14600] loss: 0.844
# [Epoch 2, Batch 14700] loss: 0.815
# [Epoch 2, Batch 14800] loss: 0.843
# [Epoch 2, Batch 14900] loss: 0.846
# [Epoch 2, Batch 15000] loss: 0.846
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 15100] loss: 0.837
# [Epoch 2, Batch 15200] loss: 0.837
# [Epoch 2, Batch 15300] loss: 0.791
# [Epoch 2, Batch 15400] loss: 0.830
# [Epoch 2, Batch 15500] loss: 0.844
# [Epoch 2, Batch 15600] loss: 0.854
# [Epoch 2, Batch 15700] loss: 0.832
# [Epoch 2, Batch 15800] loss: 0.869
# [Epoch 2, Batch 15900] loss: 0.856
# [Epoch 2, Batch 16000] loss: 0.820
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 16100] loss: 0.815
# [Epoch 2, Batch 16200] loss: 0.821
# [Epoch 2, Batch 16300] loss: 0.846
# [Epoch 2, Batch 16400] loss: 0.834
# [Epoch 2, Batch 16500] loss: 0.842
# [Epoch 2, Batch 16600] loss: 0.849
# [Epoch 2, Batch 16700] loss: 0.839
# [Epoch 2, Batch 16800] loss: 0.804
# [Epoch 2, Batch 16900] loss: 0.814
# [Epoch 2, Batch 17000] loss: 0.829
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 17100] loss: 0.829
# [Epoch 2, Batch 17200] loss: 0.861
# [Epoch 2, Batch 17300] loss: 0.797
# [Epoch 2, Batch 17400] loss: 0.808
# [Epoch 2, Batch 17500] loss: 0.825
# [Epoch 2, Batch 17600] loss: 0.798
# [Epoch 2, Batch 17700] loss: 0.807
# [Epoch 2, Batch 17800] loss: 0.853
# [Epoch 2, Batch 17900] loss: 0.832
# [Epoch 2, Batch 18000] loss: 0.843
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 18100] loss: 0.840
# [Epoch 2, Batch 18200] loss: 0.802
# [Epoch 2, Batch 18300] loss: 0.860
# [Epoch 2, Batch 18400] loss: 0.815
# [Epoch 2, Batch 18500] loss: 0.840
# [Epoch 2, Batch 18600] loss: 0.850
# [Epoch 2, Batch 18700] loss: 0.797
# [Epoch 2, Batch 18800] loss: 0.835
# [Epoch 2, Batch 18900] loss: 0.860
# [Epoch 2, Batch 19000] loss: 0.838
# ****** Model checkpoint saved at epochs 3 ******
# [Epoch 2, Batch 19100] loss: 0.825
# [Epoch 2, Batch 19200] loss: 0.850
# [Epoch 2, Batch 19300] loss: 0.804
# [Epoch 2, Batch 19400] loss: 0.798
# [Epoch 2, Batch 19500] loss: 0.811
# [Epoch 2, Batch 19600] loss: 0.850

# %%
# 포지션 8까지만 학습 해봤는데 12까지도 학습 해보기
# 이거 안되면 헤드쪽 파라미터도 0으로 만들기
